# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),#flatten은 평평하게 피는것
  tf.keras.layers.Dense(256, activation=tf.nn.relu), #이건 중간에 히든 노들 521=2^9
  
  tf.keras.layers.Dense(10, activation=tf.nn.softmax) #dense거미줄 10은 10개의 확률 예)10 20 30 ...100 
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
b= 512*10+10

# %%
a= 784*512+512

# %%
a+b
# Out:
# 407050

# %%
model.summary()   # #은 미국사람에게 넘버다 숫자 wx+b 시험시험시험
                  #784에 10개의 각각에 결과를 도출해내고 거기에 또 bias를 더해줘야되서 784*10+10이다
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_3 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                2570
# ...
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 11s 176us/sample - loss: 0.2225 - acc: 0.9358
# Epoch 2/5
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.0938 - acc: 0.9719
# Epoch 3/5
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.0630 - acc: 0.9806
# Epoch 4/5
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0446 - acc: 0.9860
# Epoch 5/5
# 60000/60000 [==============================] - 11s 176us/sample - loss: 0.0342 - acc: 0.9891

# %% [markdown]
# ####test accuarcy

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 1s 76us/sample - loss: 0.0725 - acc: 0.9787
# [0.07251493924916722, 0.9787]

# %% [markdown]
# #### train accuarcy

# %%
model.evaluate(x_train, y_train)
# Out:
# 60000/60000 [==============================] - 4s 60us/sample - loss: 0.0259 - acc: 0.9923
# [0.025897878130013124, 0.99226665]

# %% [markdown]
# ### *Real World Challenge*: Large difference between training and testing set accuracy
