# %% [markdown]
# ### About reduce_mean

# %% [markdown]
# The functionality of numpy.mean and tensorflow.reduce_mean are the *same*

# %%
import numpy as np
import tensorflow as tf

# %%
c = np.array([[3.,4], [5.,6], [6.,7]])
print(c)
# Out:
# [[3. 4.]
#  [5. 6.]
#  [6. 7.]]

# %%
m1 = np.mean(c,axis 0)#axis란 0이면 가로줄 1면 세로줄로 평균을 냄
print(m1)
# Out:
# [4.66666667 5.66666667]

# %%
m2 = tf.reduce_mean(c,axis = 1)  
with tf.Session() as sess:
    result = sess.run(m2)
    print(result)
# Out:
# [3.5 5.5 6.5]
